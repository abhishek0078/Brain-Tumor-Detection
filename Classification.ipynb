# %%
from Brain_Tumor_Detection import crop_brain_contour,prediction_fn

# %%
import cv2
import numpy as np
from tensorflow.keras.models import Model, load_model
import matplotlib.pyplot as plt

# %%
class_name = ['No','Yes']
image_path = 'C:/Users/abd17/Downloads/project brain tumor/Brain-Tumor-Detection-master/augmented data/yes/aug_Y1_0_695.jpg'
img = cv2.imread(image_path)
image = crop_brain_contour(img, plot=False)
# resize image
image = cv2.resize(image, dsize=(240, 240), interpolation=cv2.INTER_CUBIC)
# normalize values
image = image / 255.

img_batch = np.expand_dims(image, axis=0)

# %%
plt.imshow(img)
plt.show()

# %%
result = prediction_fn(image)
print(result)
# Out:
# Yes
